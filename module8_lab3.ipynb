# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik939075/karthik_FMML_LABS_PROJECTS/blob/main/module8_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-22 17:41:25--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   168MB/s    in 0.4s
#
# 2025-03-22 17:41:27 (168 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2210   1707.00819v1  Complex systems can be modelled at various lev...  stat
# 1408   1611.00847v3  Recent research in the deep learning field has...    cs
# 13472   0803.2925v1  Crucial to an Evolutionary Algorithm's perform...    cs
# 9741   1802.05622v1  Geostatistical modeling of petrophysical prope...  stat
# 34850   0801.1883v1  We introduce a novel online Bayesian method fo...    cs
# ...             ...                                                ...   ...
# 6086   1607.00485v1  In this paper, we consider the joint task of s...  stat
# 38821  1505.04617v1  Sparse representation based classification (SR...    cs
# 14284  1609.03240v2  We consider the non-square matrix sensing prob...  stat
# 22695  1704.07520v2  Stein variational gradient descent (SVGD) is a...  stat
# 5101    1309.7522v1  The examination of Osteoarthritis disease thro...    cs
#
#                                                    title  year  \
# 2210    Causal Consistency of Structural Equation Models  2017
# 1408   Deep Convolutional Neural Network Design Patterns  2016
# 13472  Equivalence of Probabilistic Tournament and Po...  2008
# 9741   Conditioning of three-dimensional generative a...  2018
# 34850  D-optimal Bayesian Interrogation for Parameter...  2008
# ...                                                  ...   ...
# 6086   Group Sparse Regularization for Deep Neural Ne...  2016
# 38821  Joint Representation Classification for Collec...  2015
# 14284  Non-square matrix sensing without spurious loc...  2016
# 22695  Stein Variational Gradient Descent as Gradient...  2017
# 5101   An Application of Backpropagation Artificial N...  2013
#
#                                                 keywords
# 2210   [consistent, predictions, interventions, forma...
# 1408   [architectures, applications, inexperienced, p...
# 13472  [evolutionary, algorithms, performance, select...
# 9741   [geostatistical, petrophysical, properties, in...
# 34850  [introduce, identification, recurrent, techniq...
# ...                                                  ...
# 6086   [simultaneously, optimizing, generally, separa...
# 38821  [representation, classification, popularly, ap...
# 14284  [restricted, assumptions, formulation, represe...
# 22695  [variational, deterministic, algorithm, iterat...
# 5101   [examination, osteoarthritis, rheumatology, cl...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2210     [consistent, predictions, interventions, forma...
# 1408     [architectures, applications, inexperienced, p...
# 13472    [evolutionary, algorithms, performance, select...
# 9741     [geostatistical, petrophysical, properties, in...
# 34850    [introduce, identification, recurrent, techniq...
#                                ...
# 23025    [theoretically, investigating, statistical, pr...
# 32560    [representations, encourages, performance, cla...
# 32681    [automatically, clustering, algorithms, execut...
# 10431    [optimization, manifolds, developing, nonlinea...
# 24428    [conducted, determine, thickness, coherence, t...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8773 words.
# Out of those 4559 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d16eded1-a4e7-402e-aac8-d9e4c2467822" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d16eded1-a4e7-402e-aac8-d9e4c2467822")) {                    Plotly.newPlot(                        "d16eded1-a4e7-402e-aac8-d9e4c2467822",                        [{"x":["scenarios","unobservable","formalise","introducing","modelling","stationary","transformations","predictions","following","behaviour","irrelevant","importance","different","variables","specified","consistent","description","interventions","structural","dynamical","interpretation","aggregate","consistency","practitioners","underlying","stagewise","applications","including","innovations","available","convolutional","knowledge","collective","designing","preliminary","contained","architecture","architectures","architectural","therefore","principles","translating","equivalence","quadratic","performance","selection","practical","operators","probabilistic","polynomial","equivalent","investigate","evolutionary","mathematically","tournament","algorithms","generalisations","particular","generative","constrain","integrated","generation","contribution","simulation","simulations","conditional","conditioned","reservoir","workflows","geostatistical","successful","properties","generating","adversarial","perceptual","leverages","represent","stochastic","conditioning","constrained","technique","evaluation","unconditional","differentiable","dimensional","discriminator","recurrent","principle","identification","derivation","parameters","parameter","experiences","analytical","concerning","interrogation","optimality","estimation","approximation","information","introduce","attractive","rendering","requirements","approaches","computation","efficient","expensive","nontrivial","coordinate","innovative","transport","frequency","paramount","viewpoint","computational","precomputed","prohibitively","frequencies","annotations","perception","multimedia","languages","differences","application","affective","multilingual","connected","framework","embeddings","experiment","representations","sentiment","exploring","clustering","attention","judgements","effective","commonalities","relatedness","crowdsourced","linguistics","efficiency","optimization","soundness","variational","resulting","shortcomings","theoretical","arguments","reformulation","classical","inference","theoretic","increased","encountered","solutions","difficulties","formalism","uniqueness","dimensionality","interactivity","techniques","visualization","steerable","progressive","refinements","meaningful","constrains","distributed","effectiveness","interaction","efficiently","approximated","visualized","initialization","exploration","interactive","illustrate","intermediate","reduction","demonstrate","improving","analytics","embedding","controllable","interpolation","transforming","transformation","estimated","prediction","predictor","concludes","predicting","accordingly","developers","shrinking","splitting","sensitivity","distribution"],"y":[84,5,3,52,47,26,46,93,96,34,16,87,740,132,34,80,73,4,83,17,48,15,48,19,122,2,456,259,5,321,390,342,16,38,49,20,243,145,14,150,38,17,25,34,900,163,141,57,142,63,40,157,55,14,3,619,1,296,113,10,65,155,72,65,55,101,19,10,4,0,68,184,108,101,27,30,132,121,14,68,237,240,2,23,192,13,158,38,94,12,244,124,16,21,15,1,23,204,109,693,335,22,12,60,460,160,442,74,9,21,14,6,64,2,25,301,1,5,14,58,47,17,106,57,256,6,17,76,567,73,88,191,47,41,149,193,4,241,2,6,11,15,161,313,4,48,166,14,178,26,4,110,199,48,51,14,158,32,21,8,54,4,352,30,4,12,6,38,7,95,223,67,150,17,4,25,55,43,65,42,107,552,103,15,108,7,18,12,71,66,216,16,6,69,20,7,3,15,33,201],"type":"bar"},{"x":["scenarios","unobservable","formalise","introducing","modelling ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4559,), (4559, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Context</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dependent</span> <span style='background-color:rgba(0, 255, 0, 0.35897435897435903);'>Similarity</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.46938775510204084);'>Attribute</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style=''>two</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 0.3866666666666667);'>mechanisms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>context</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style='background-color:rgba(0, 255, 0, 0.35897435897435903);'>similarity</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>measures</span> <span style=''>are</span> <span style=''>studied</span> <span style=''>and</span> <span style=''>compared</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>measure</span> <span style=''>based</span> <span style=''>on</span> <span style=''>subset</span> <span style=''>size</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>and</span> <span style=''>its</span> <span style=''>metrization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>are</span> <span style=''>given</span> <span style=''>It</span> <span style=''>is</span> <span style=''>also</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>while</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.46938775510204084);'>attribute</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>measures</span> <span style=''>are</span> <span style=''>metrics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weighting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dissimilarity</span> <span style=''>measures</span> <span style=''>are</span> <span style=''>usually</span> <span style=''>non</span> <span style=''>metric</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>MML</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>Neyman</span> <span style=''>Scott</span> <br/><br/><span style=''>Strict</span> <span style=''>Minimum</span> <span style=''>Message</span> <span style=''>Length</span> <span style=''>(SMML)</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>method</span> <span style=''>widely</span> <span style=''>cited</span> <span style=''>(but</span> <span style=''>only</span> <span style=''>with</span> <span style=''>informal</span> <span style=''>arguments)</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimations</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>problems</span> <span style=''>It</span> <span style=''>is</span> <span style=''>however</span> <span style=''>almost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariably</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intractable</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>for</span> <span style=''>which</span> <span style=''>reason</span> <span style=''>only</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>it</span> <span style=''>(known</span> <span style=''>as</span> <span style=''>MML</span> <span style=''>algorithms)</span> <span style=''>are</span> <span style=''>ever</span> <span style=''>used</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style=''>Neyman</span> <span style=''>Scott</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>problem</span> <span style=''>an</span> <span style=''>oft</span> <span style=''>cited</span> <span style=''>showcase</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>of</span> <span style=''>MML</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>even</span> <span style=''>with</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>prior</span> <span style=''>neither</span> <span style=''>SMML</span> <span style=''>nor</span> <span style=''>its</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style=''>for</span> <span style=''>it</span> <span style=''>thereby</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>counterexample</span> <span style=''>to</span> <span style=''>the</span> <span style=''>general</span> <span style=''>claim</span> <span style=''>This</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>known</span> <span style=''>explicit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>an</span> <span style=''>SMML</span> <span style=''>solution</span> <span style=''>for</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>hi ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Scan</span> <span style=''>B</span> <span style='background-color:rgba(255, 0, 0, 0.49999999999999994);'>Statistic</span> <span style=''>for</span> <span style=''>Kernel</span> <span style=''>Change</span> <span style=''>Point</span> <span style='background-color:rgba(0, 255, 0, 0.4900221729490022);'>Detection</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.38709677419354854);'>Detecting</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>emergence</span> <span style=''>of</span> <span style=''>an</span> <span style=''>abrupt</span> <span style=''>change</span> <span style=''>point</span> <span style=''>is</span> <span style=''>a</span> <span style=''>classic</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.39325842696629204);'>statistics</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>Kernel</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.6993464052287581);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.39325842696629204);'>statistics</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style=''>this</span> <span style=''>task</span> <span style=''>which</span> <span style=''>enjoy</span> <span style=''>fewer</span> <span style='background-color:rgba(255, 0, 0, 0.41871921182266014);'>assumptions</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3474320241691842);'>distributions</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5371900826446281);'>parametric</span> <span style=''>approach</span> <span style=''>and</span> <span style=''>can</span> <span style=''>handle</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3447098976109215);'>dimensional</span> <span style=''>data</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>scenario</span> <span style=''>when</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.66);'>background</span> <span style=''>data</span> <span style=''>is</span> <span style=''>large</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>two</span> <span style=''>related</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>kernel</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.39325842696629204);'>statistics</span> <span style=''>for</span> <span style=''>change</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.4900221729490022);'>detection</span> <span style=''>which</span> <span style=''>are</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>the</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>B</span> <span style='background-color:rgba(255, 0, 0, 0.39325842696629204);'>statistics</span> <span style=''>A</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style=''>result</span> <span style=''>of</span> <span style=''>the</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tail</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>hurdle</span> <span style=''>model</span> <br/><br/><span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>composite</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>for</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>modeling</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interesting</span> <span style=''>and</span> <span style=''>common</span> <span style=''>values</span> <span style=''>such</span> <span style=''>as</span> <span style=''>excess</span> <span style=''>zeros</span> <span style=''>or</span> <span style=''>missing</span> <span style=''>values</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>and</span> <span style=''>the</span> <span style=''>hurdle</span> <span style=''>method</span> <span style=''>which</span> <span style=''>is</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>zero</span> <span style=''>inflated</span> <span style=''>counts</span> <span style=''>The</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manufacturing</span> <span style=''>data</span> <span style=''>set</span> <span style=''>and</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>missing</span> <span style=''>value</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>imputation</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07656859269762496)
# 	knowledge (0.12123360510457284)
# 	architecture (0.08613966678482808)
# 	processing (0.11272598369372563)
# 	information (0.2456575682382134)
# 	segmentation (0.07337823466855725)
# 	detection (0.11910669975186104)
# 	different (0.2623183268344559)
# 	convolutional (0.1382488479262673)
# 	recognition (0.14214817440623892)
#
# Some Statistics words are:
# 	theoretical (0.15866599292572006)
# 	stochastic (0.14047498736735725)
# 	algorithm (0.38453764527539164)
# 	variables (0.1480545730166751)
# 	statistical (0.17028802425467407)
# 	estimation (0.1793835270338555)
# 	distribution (0.1975745325922183)
# 	dimensional (0.19909044972208187)
# 	inference (0.20768064679130874)
# 	regression (0.1869631126831733)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="50a2fb3c-7e0a-4c24-ab4d-4e5257f1e7c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50a2fb3c-7e0a-4c24-ab4d-4e5257f1e7c5")) {                    Plotly.newPlot(                        "50a2fb3c-7e0a-4c24-ab4d-4e5257f1e7c5",                        [{"x":["scenarios","unobservable","formalise","introducing","modelling","stationary","transformations","predictions","following","behaviour","irrelevant","importance","different","variables","specified","consistent","description","interventions","structural","dynamical","interpretation","aggregate","consistency","practitioners","underlying","stagewise","applications","including","innovations","available","convolutional","knowledge","collective","designing","preliminary","contained","architecture","architectures","architectural","therefore","principles","translating","equivalence","quadratic","performance","selection","practical","operators","probabilistic","polynomial","equivalent","investigate","evolutionary","mathematically","tournament","algorithms","generalisations","particular","generative","constrain","integrated","generation","contribution","simulation","simulations","conditional","conditioned","reservoir","workflows","geostatistical","successful","properties","generating","adversarial","perceptual","leverages","represent","stochastic","conditioning","constrained","technique","evaluation","unconditional","differentiable","dimensional","discriminator","recurrent","principle","identification","derivation","parameters","parameter","experiences","analytical","concerning","interrogation","optimality","estimation","approximation","information","introduce","attractive","rendering","requirements","approaches","computation","efficient","expensive","nontrivial","coordinate","innovative","transport","frequency","paramount","viewpoint","computational","precomputed","prohibitively","frequencies","annotations","perception","multimedia","languages","differences","application","affective","multilingual","connected","framework","embeddings","experiment","representations","sentiment","exploring","clustering","attention","judgements","effective","commonalities","relatedness","crowdsourced","linguistics","efficiency","optimization","soundness","variational","resulting","shortcomings","theoretical","arguments","reformulation","classical","inference","theoretic","increased","encountered","solutions","difficulties","formalism","uniqueness","dimensionality","interactivity","techniques","visualization","steerable","progressive","refinements","meaningful","constrains","distributed","effectiveness","interaction","efficiently","approximated","visualized","initialization","exploration","interactive","illustrate","intermediate","reduction","demonstrate","improving","analytics","embedding","controllable","interpolation","transforming","transformation","estimated","prediction","predictor","concludes","predicting","accordingly","developers","shrinking","splitting","sensitivity","distribution","misclassification","observations","alternative","guidelines","invariant","statement","furthermore","individual","constructing","probability","candidate","characterized","experimental","highlight","factorization","geographical","propensity","recommendation","prevalence","inventory","recommending","recommender","constraints","personalized","posterior","achieving","hierarchical","significantly","competitive","precision","contribute","novelties","principled","significance","compression","uncertainties","determine","established","declarative","practices","typically","decompositions","instrumental","statistics","statisticians","constitute","associated","statistical","extracted","representation","excessive","superpixe ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	geostatistical
# 	whitening
# 	marginalized
# 	passenger
# 	delineates
# 	thermostat
# 	censoring
# 	practicing
# 	clinicians
# 	dispersion
# 	embarrassingly
# 	tibshirani
# 	subpopulation
# 	distributionally
# 	equitability
# 	recasting
# 	matchings
# 	therapeutic
# 	refitting
# 	penalised
# Some words which never appear in Statistics papers:
# 	multimedia
# 	affective
# 	judgements
# 	interactivity
# 	steerable
# 	progressive
# 	declarative
# 	superpixel
# 	undersegmentation
# 	adherence
# 	localizing
# 	revisions
# 	expressible
# 	revisable
# 	biobjective
# 	pheromone
# 	reinforced
# 	cooperative
# 	coevolution
# 	reevaluate

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0516646830846227e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
